# %%
import tweepy 
import pandas as pd
import numpy as np
import seaborn as sns
import textblob

# %%
consumer_key = "3nk6TG6I9jKEnYU9Uk7Lkvhbk"
consumer_secret = "CPm4HONYZAGNqU44OG7ri2mmdbnTFqZH9hhcBLaJJSqVtq4KFq"
access_token = "1567071529-VWAWdo29AtRDjQ3mPZgP20s0QwsUMz9KMZgUKLG"
access_token_secret = "lLNXz59sq2yS41uPDgTQh83EP91Hq0FMZwt0GyrXYxb61"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
api = tweepy.API(auth)
tweets = api.user_timeline(screen_name = "realDonaldTrump", count=200)
for tweet in tweets[:5]:
    print(tweet.text)
# Out:
# ....the possible exception of another Republican President, the late, great, Abraham Lincoln...and it’s not even cl… https://t.co/CYdTVkhvh6

# %%
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
data['len'] = np.array([len(tweet.text) for tweet in tweets])
data['Date']= np.array([tweet.created_at for tweet in tweets])
data['RTs'] = np.array([tweet.retweet_count for tweet in tweets])
data['Likes'] = np.array([tweet.favorite_count for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])

# %%
sns.lineplot(x='Date', y = 'len', data=data)

# %%
sns.lineplot(x = 'Date', y = 'Likes', data=data)

# %%
sns.lineplot(x='Date', y='RTs', data=data)
